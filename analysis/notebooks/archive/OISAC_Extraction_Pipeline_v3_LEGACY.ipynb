# %% [markdown]
# # 🚀 O-ISAC Extraction Pipeline v3.0
#
# **Optimized PRISMA-compliant data extraction for O-ISAC systematic review**
#
# ## Features:
# - ✅ **Resume Support** - Only processes new/changed PDFs
# - ✅ **v2.0 Schema** - PRISMA Protocol Section 9 aligned
# - ✅ **GPU Optimized** - Batched visual analysis
# - ✅ **Async LLM** - Parallel Groq API calls
#
# ## Requirements:
# - GPU Runtime (A100 recommended)
# - GROQ_API_KEY in Colab secrets
# - Google Drive mounted with PDFs

# %% [markdown]
# ## 📦 Step 1: Install Dependencies

# %%
# Install required packages
# !pip install -q marker-pdf openai nest_asyncio transformers torch pillow pandas

# Verify marker installation
import shutil
if shutil.which('marker_single'):
    print('✅ Marker installed successfully')
else:
    print('⚠️ Marker not in PATH - may need runtime restart')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.9/188.9 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 127.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.2/223.2 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 112.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 117.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 58.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 🔗 Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Verify project path
import os
PROJECT = '/content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST'
PDF_DIR = os.path.join(PROJECT, 'data/retrieved_docs')

if os.path.exists(PDF_DIR):
    pdfs = [f for f in os.listdir(PDF_DIR) if f.endswith('.pdf')]
    print(f'✅ Found {len(pdfs)} PDFs in retrieved_docs')
else:
    print('❌ PDF directory not found!')
# Out:
# Mounted at /content/drive
# ✅ Found 32 PDFs in retrieved_docs

# %% [markdown]
# ## ⚙️ Step 3: Load Pipeline Module

# %%
# Add notebooks folder to path and import pipeline
import sys
sys.path.insert(0, os.path.join(PROJECT, 'analysis/notebooks'))

from extraction_pipeline_v3 import (
    Config, CheckpointManager,
    phase1_marker_conversion,
    phase2_visual_analysis,
    phase3_llm_extraction,
    run_full_pipeline
)

# Initialize directories
Config.init_dirs()
print('✅ Pipeline loaded')
print(f'📁 Output: {Config.OUTPUT_DIR}')
# Out:
# 🌍 Environment: Google Colab
# ✅ Pipeline loaded
# 📁 Output: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/extraction_results_v3

# %% [markdown]
# ## 🔑 Step 4: Verify API Key
#
# Make sure `GROQ_API_KEY` is set in Colab Secrets (🔑 icon in left sidebar)

# %%
from google.colab import userdata
try:
    key = userdata.get('GROQ_API_KEY')
    print(f'✅ GROQ_API_KEY found ({key[:8]}...)')
except:
    print('❌ GROQ_API_KEY not found! Add it to Colab Secrets.')
# Out:
# ✅ GROQ_API_KEY found (gsk_XXCl...)

# %% [markdown]
# ---
# ## 🎯 Step 5: Run Pipeline
#
# Choose your run mode:
# - **Test**: Process first 3 papers
# - **Full**: Process all papers
# - **Resume**: Continue from checkpoint

# %%
# ========================================
# 🧪 TEST RUN (First 3 papers)
# ========================================
results = run_full_pipeline(limit=3)
print(f'\n📊 Extracted {len(results)} papers')
# Out:
# ...
# 🚀 O-ISAC EXTRACTION PIPELINE v3.0
# ...
# 📅 Started: 2025-12-10 20:13
#
# ...
# 📄 PHASE 1: PDF → MARKDOWN (Marker)
# ...
# Found 32 PDFs
#    ⏩ O_ISAC_001 - already processed, skipping
#    ⏩ O_ISAC_002 - already processed, skipping
#    ⏩ O_ISAC_003 - already processed, skipping
#    ⏩ O_ISAC_004 - already processed, skipping
#    ⏩ O_ISAC_005 - already processed, skipping
#    ⏩ O_ISAC_006 - already processed, skipping
#    ⏩ O_ISAC_007 - already processed, skipping
#    ⏩ O_ISAC_008 - already processed, skipping
#    ⏩ O_ISAC_009 - already processed, skipping
#    ⏩ O_ISAC_010 - already processed, skipping
#    ⏩ O_ISAC_011 - already processed, skipping
#    ⏩ O_ISAC_012 - already processed, skipping
#    ⏩ O_ISAC_013 - already processed, skipping
#    ⏩ O_ISAC_014 - already processed, skipping
#    ⏩ O_ISAC_015 - already processed, skipping
#    ⏩ O_ISAC_016 - already processed, skipping
#    ⏩ O_ISAC_017 - already processed, skipping
#    ⏩ O_ISAC_018 - already processed, skipping
# ...

# %%
# SADECE RESİMLERİ KURTARMAK İÇİN BU KODU KULLANIN
from extraction_pipeline_v3 import Config, CheckpointManager, phase1_marker_conversion

Config.init_dirs()
checkpoint = CheckpointManager(Config.CHECKPOINT_FILE)

# force_all=False diyoruz ki sadece eksikleri tamamlasın
phase1_marker_conversion(checkpoint, force_all=False)

print("✅ Resim kurtarma operasyonu bitti!")
# Out:
# ...
# 📄 PHASE 1: PDF → MARKDOWN (Marker)
# ...
# Found 32 PDFs
#    ⏩ O_ISAC_001 - already processed, skipping
#    ⏩ O_ISAC_002 - already processed, skipping
#    ⏩ O_ISAC_003 - already processed, skipping
#    ⏩ O_ISAC_004 - already processed, skipping
#    ⏩ O_ISAC_005 - already processed, skipping
#    ⏩ O_ISAC_006 - already processed, skipping
#    ⏩ O_ISAC_007 - already processed, skipping
#    ⏩ O_ISAC_008 - already processed, skipping
#    ⏩ O_ISAC_009 - already processed, skipping
#    ⏩ O_ISAC_010 - already processed, skipping
#    ⏩ O_ISAC_011 - already processed, skipping
#    ⏩ O_ISAC_012 - already processed, skipping
#    ⏩ O_ISAC_013 - already processed, skipping
#    ⏩ O_ISAC_014 - already processed, skipping
#    ⏩ O_ISAC_015 - already processed, skipping
#    ⏩ O_ISAC_016 - already processed, skipping
#    ⏩ O_ISAC_017 - already processed, skipping
#    ⏩ O_ISAC_018 - already processed, skipping
#    ⏩ O_ISAC_019 - already processed, skipping
# ...

# %%
import glob
import os

base_dir = "/content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/processed_markdowns"
target = "O_ISAC_030"

# ** ekleyerek ve recursive=True diyerek alt klasörlere dalıyoruz
path = os.path.join(base_dir, target, "**", "*.jpg")
images = glob.glob(path, recursive=True)

if len(images) > 0:
    print(f"✅ {target}: {len(images)} adet resim bulundu! (Alt klasörlerin derinliklerinde...)")
    # Kanıt olarak ilk resmin yolunu basalım
    print(f"   Örnek: {images[0]}")
else:
    print(f"❌ {target}: Hala bulunamadı.")
# Out:
# ❌ O_ISAC_030: Hala bulunamadı.

# %%
# ========================================
# 🚀 FULL RUN (All papers)
# ========================================
# Uncomment to run all:
# results = run_full_pipeline()
# print(f'\n📊 Extracted {len(results)} papers')

# %%
# ========================================
# ⏭️ SKIP PHASES (Resume from checkpoint)
# ========================================
# If Marker/Visual already done, skip to LLM:
# results = run_full_pipeline(skip_phase1=True, skip_phase2=True)

# %%
# ========================================
# 🧪 TEST NEW V2.0 PROMPT (1-2 papers)
# ========================================
# Bu test, yeni prompt'un çalışıp çalışmadığını kontrol eder
# Marker ve Visual zaten yapıldı, sadece LLM extraction çalışır

results = run_full_pipeline(skip_phase1=True, skip_phase2=True, limit=2)
print(f'\n📊 Extracted {len(results)} papers')
# Out:
# ...
# 🚀 O-ISAC EXTRACTION PIPELINE v3.0
# ...
# 📅 Started: 2025-12-08 19:48
#
# ...
# 🧠 PHASE 3: LLM EXTRACTION (Groq)
# ...
# Papers to extract: 2
#
# ✅ Success: 2
# ❌ Errors: 0
#
# 📁 Saved: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/extraction_results_v3/extraction_v3.json
# 📊 Saved: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/extraction_results_v3/extraction_v3.csv
#
#      Paper_ID                                              Title  Year Venue  \
# 0  O_ISAC_001  Modulation Strategies for Robust Optical Wirel...  2025  IEEE
# 1  O_ISAC_002  Photonic Terahertz Integrated Sensing and Comm...  2025  IEEE
#
#    Medium_Class Carrier_Band Environment        Topology  \
# 0  wireless_vlc      visible      indoor  point_to_point
# 1  wireless_fso    terahertz      indoor  point_to_point
#
#               Evidence_Type    RIS  ...  Sensing_Range_m  \
# 0              experimental  False  ...                2
# ...

# %%
# ========================================
# 📊 DETAILED JSON INSPECTION
# ========================================
import json

json_path = Config.OUTPUT_DIR + '/extraction_v3.json'
with open(json_path) as f:
    data = json.load(f)

# İlk paper'ı detaylı göster
print("=" * 60)
print("📄 PAPER 1 - FULL JSON OUTPUT")
print("=" * 60)
print(json.dumps(data[0], indent=2, ensure_ascii=False)[:5000])  # İlk 5000 karakter
# Out:
# ...
# 📄 PAPER 1 - FULL JSON OUTPUT
# ...
# {
#   "Paper_ID": "O_ISAC_001",
#   "Study_Level": {
#     "title": "Modulation Strategies for Robust Optical Wireless Communications and Sensing in 6G",
#     "authors": "Bruno M.S.R. Rosmaninho, Paulo P. Monteiro, Vinicius. N.H. Silva, Maria C.R. Medeiros",
#     "year": 2025,
#     "venue": "IEEE",
#     "doi": "NR",
#     "document_type": "journal",
#     "oisac_medium_class": "wireless_vlc",
#     "carrier_band": "visible",
#     "operational_environment": "indoor",
#     "link_topology": "point_to_point",
#     "mobility_context": "static",
#     "application_domain": [
#       "indoor_positioning",
#       "6g_networks"
#     ],
#     "scenario_description": "VLC system using CE-OFDM for communication and localization",
#     "evidence_type": [
#       "experimental"
#     ],
#     "validation_baselines_present": false,
#     "reproducibility_artifacts": "insufficient",
#     "ris_present": false,
#     "opa_present": false,
# ...

# %%
# ========================================
# 📈 QUALITY ASSESSMENT SUMMARY
# ========================================
print("\n" + "=" * 60)
print("📊 QUALITY ASSESSMENT SUMMARY")
print("=" * 60)

for paper in data:
    qa = paper.get("Quality_Assessment", {})
    sl = paper.get("Study_Level", {})
    exp_count = len(paper.get("Experiments", []))

    print(f"\n📄 {paper['Paper_ID']} - {sl.get('title', 'NR')[:50]}...")
    print(f"   Experiments: {exp_count}")
    print(f"   Medium: {sl.get('oisac_medium_class', 'NR')}")
    print(f"   TQAF Scores: {qa.get('tqaf_modelling_fidelity', 'NR')}/{qa.get('tqaf_validation_strength', 'NR')}/{qa.get('tqaf_metric_completeness', 'NR')}/{qa.get('tqaf_reproducibility', 'NR')}")
    print(f"   Both S&C Metrics: {qa.get('both_sc_metrics_reported', 'NR')}")
    print(f"   Tradeoff Analyzed: {qa.get('tradeoff_explicitly_analyzed', 'NR')}")
# Out:
# ...
# 📊 QUALITY ASSESSMENT SUMMARY
# ...
#
# 📄 O_ISAC_001 - Modulation Strategies for Robust Optical Wireless ...
#    Experiments: 1
#    Medium: wireless_vlc
#    TQAF Scores: 1/1/1/1
#    Both S&C Metrics: True
#    Tradeoff Analyzed: True
#
# 📄 O_ISAC_002 - Photonic Terahertz Integrated Sensing and Communic...
#    Experiments: 1
#    Medium: wireless_fso
#    TQAF Scores: 2/2/2/1
#    Both S&C Metrics: True
#    Tradeoff Analyzed: False

# %% [markdown]
# ## 📊 Step 6: View Results

# %%
import pandas as pd

csv_path = os.path.join(Config.OUTPUT_DIR, 'extraction_v3.csv')
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print(f'📊 Total experiments: {len(df)}')
    print(f'📄 Total papers: {df["Paper_ID"].nunique()}')
    print('\n--- Sample Data ---')
    display(df.head(10))
else:
    print('No results yet - run the pipeline first!')
# Out:
# 📊 Total experiments: 5
# 📄 Total papers: 3
#
# --- Sample Data ---
#      Paper_ID                                              Title  Year  \
# 0  O_ISAC_001  Modulation Strategies for Robust Optical Wirel...  2025
# 1  O_ISAC_002  Photonic Terahertz Integrated Sensing and Comm...  2025
# 2  O_ISAC_002  Photonic Terahertz Integrated Sensing and Comm...  2025
# 3  O_ISAC_003  Analysis of Visible Light-Based ISAC Channel C...  2025
# 4  O_ISAC_003  Analysis of Visible Light-Based ISAC Channel C...  2025
#
#          Medium Exp_ID                                           Scenario  \
# 0  wireless_vlc     E1                                 VLC CE-OFDM system
# 1  wireless_fso     E1  Radar-centric photonic terahertz integrated se...
# 2  wireless_fso     E2             Multi-channel photonic THz-ISAC system
# 3  wireless_vlc     E1                                 Monostatic Sensing
# 4  wireless_vlc     E2                                  Bi-static Sensing
#
# ...

# %%
# Distribution analysis
if 'df' in dir() and len(df) > 0:
    print('\n📈 Medium Distribution:')
    print(df['Medium'].value_counts())

    print('\n📈 ISAC Waveform Relationship:')
    print(df['ISAC_Relationship'].value_counts())

    print('\n📈 Coupling Mode:')
    print(df['Coupling_Mode'].value_counts())
# Out:
# 📈 Medium Distribution:
# Medium
# wireless_vlc    3
# wireless_fso    2
# Name: count, dtype: int64
#
# 📈 ISAC Waveform Relationship:
# ISAC_Relationship
# single_dual_function    3
# NR                      2
# Name: count, dtype: int64
#
# 📈 Coupling Mode:
# Coupling_Mode
# joint_waveform    3
# NR                2
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 🔧 Utility: Check Checkpoint Status

# %%
# View checkpoint status
import json
checkpoint_path = os.path.join(Config.OUTPUT_DIR, 'checkpoint.json')
if os.path.exists(checkpoint_path):
    with open(checkpoint_path) as f:
        cp = json.load(f)
    print(f'✅ Processed: {len(cp.get("processed", {}))} papers')
    print(f'❌ Errors: {len(cp.get("errors", []))}')
    print(f'🕐 Last run: {cp.get("last_run", "Never")}')
else:
    print('No checkpoint file yet')

# %%
# Force reprocess all (clears checkpoint)
# Uncomment to reset:
# import os
# checkpoint_path = os.path.join(Config.OUTPUT_DIR, 'checkpoint.json')
# if os.path.exists(checkpoint_path):
#     os.remove(checkpoint_path)
#     print('🗑️ Checkpoint cleared!')

# %%
# ========================================
# 🧪 TEST SINGLE PAPER: O_ISAC_029
# ========================================
import json
import asyncio
import os
from extraction_pipeline_v3 import extract_single_paper

# Doğru path (hardcoded)
paper_id = "O_ISAC_029"
INTERMEDIATE_DIR = "/content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/processed_markdowns"
paper_folder = os.path.join(INTERMEDIATE_DIR, paper_id, paper_id)

print(f"📁 Looking in: {paper_folder}")

# Markdown oku
md_file = os.path.join(paper_folder, f"{paper_id}.md")
if os.path.exists(md_file):
    with open(md_file, 'r', encoding='utf-8') as f:
        md_content = f.read()
    print(f"✅ Markdown: {len(md_content)} chars")
else:
    md_content = ""
    print(f"❌ Markdown not found")

# Visual analiz
visual_path = os.path.join(paper_folder, "visual_analysis.txt")
visual_content = open(visual_path, 'r', encoding='utf-8').read() if os.path.exists(visual_path) else ""

# Semaphore ekle ve çalıştır
semaphore = asyncio.Semaphore(5)
result = asyncio.run(extract_single_paper(paper_id, md_content, visual_content, semaphore))

print("\n" + "="*60)
print("📊 O_ISAC_029 EXTRACTION RESULT")
print("="*60)
print(json.dumps(result, indent=2, ensure_ascii=False)[:10000])
# Out:
# 📁 Looking in: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/processed_markdowns/O_ISAC_029/O_ISAC_029
# ✅ Markdown: 79038 chars
#
# ...
# 📊 O_ISAC_029 EXTRACTION RESULT
# ...
# {
# ...

# %%
# ========================================
# 🚀 FULL RUN - TÜM 32 PAPER
# ========================================
# Phase 1 & 2 zaten yapıldı, sadece LLM extraction çalışır
results = run_full_pipeline(skip_phase1=True, skip_phase2=True)
print(f'\n📊 Toplam çıkarılan paper: {len(results)}')
# Out:
# ...
# 🚀 O-ISAC EXTRACTION PIPELINE v3.0
# ...
# 📅 Started: 2025-12-08 20:04
#
# ...
# 🧠 PHASE 3: LLM EXTRACTION (Groq)
# ...
# Papers to extract: 32
#
# ✅ Success: 32
# ❌ Errors: 0
#
# 📁 Saved: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/extraction_results_v3/extraction_v3.json
# 📊 Saved: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/extraction_results_v3/extraction_v3.csv
#
#      Paper_ID                                              Title  Year  \
# 0  O_ISAC_001  Modulation Strategies for Robust Optical Wirel...  2025
# 1  O_ISAC_002  Photonic Terahertz Integrated Sensing and Comm...  2025
# 2  O_ISAC_003  Analysis of Visible Light-Based ISAC Channel C...  2025
# 3  O_ISAC_003  Analysis of Visible Light-Based ISAC Channel C...  2025
# 4  O_ISAC_004  Adiabatic-tapered few-mode-fiber-based system ...  2025
# 5  O_ISAC_005  Integrated Sensing and Communication for UAV T...  2024
# ...

# %%
# JSON sonuçlarını kontrol et
import json
json_path = Config.OUTPUT_DIR + '/extraction_v3.json'
with open(json_path) as f:
    data = json.load(f)

print(f"📄 Toplam paper: {len(data)}")
for p in data[:3]:  # İlk 3 paper
    print(f"\n• {p['Paper_ID']} - {p.get('Study_Level', {}).get('title', 'N/A')[:60]}...")
# Out:
# 📄 Toplam paper: 32
#
# • O_ISAC_001 - Modulation Strategies for Robust Optical Wireless Communicat...
#
# • O_ISAC_002 - Photonic Terahertz Integrated Sensing and Communication (ISA...
#
# • O_ISAC_003 - Analysis of Visible Light-Based ISAC Channel Characteristics...

# %%
import pandas as pd
df = pd.read_csv(Config.OUTPUT_DIR + '/extraction_v3.csv')
print(f"📊 Toplam experiment: {len(df)}")
print(f"📄 Unique paper: {df['Paper_ID'].nunique()}")
print(f"\n📈 Medium Dağılımı:")
print(df['Medium_Class'].value_counts())
# Out:
# 📊 Toplam experiment: 36
# 📄 Unique paper: 32
#
# 📈 Medium Dağılımı:
# Medium_Class
# cabled_fibre                14
# wireless_fso                 8
# wireless_vlc                 7
# hybrid                       6
# wireless_retroreflective     1
# Name: count, dtype: int64

# %%
# ========================================
# 🔍 O_ISAC_029 DETAYLI GÖRÜNTÜLEME
# ========================================
import json

json_path = Config.OUTPUT_DIR + '/extraction_v3.json'
with open(json_path) as f:
    data = json.load(f)

# O_ISAC_029'u bul
paper_029 = next((p for p in data if p['Paper_ID'] == 'O_ISAC_029'), None)

if paper_029:
    print("=" * 70)
    print("📄 O_ISAC_029 - FULL EXTRACTION")
    print("=" * 70)
    print(json.dumps(paper_029, indent=2, ensure_ascii=False))
else:
    print("❌ O_ISAC_029 bulunamadı!")
# Out:
# ...
# 📄 O_ISAC_029 - FULL EXTRACTION
# ...
# {
#   "Paper_ID": "O_ISAC_029",
#   "Study_Level": {
#     "title": "THz Integrated Sensing and Communication With Full-Photonic Direct LFM Reception and De-Chirping for D-Band Fiber-Wireless Network",
#     "authors": "Boyu Dong, Zhongya Li, Sizhe Xing, Yinjun Liu, Junhao Zhao, Ouhan Huang, Junlian Jia, Jianyang Shi, Yingjun Zhou, Haipeng Wang, Nan Chi, Junwen Zhang",
#     "year": 2025,
#     "venue": "IEEE Transactions on Microwave Theory and Techniques",
#     "doi": "10.1109/TMTT.2025.3549729",
#     "document_type": "journal",
#     "oisac_medium_class": "hybrid",
#     "carrier_band": "D-band",
#     "operational_environment": "lab",
#     "link_topology": "point_to_point",
#     "mobility_context": "static",
#     "application_domain": [
#       "6g_networks"
#     ],
#     "scenario_description": "A D-band photonic-based ISAC system for fiber-wireless networks with full-photonic direct LFM reception and de-chirping",
#     "evidence_type": [
# ...

# %%
# Reload the test module to pick up the changes
import importlib
import test_v21_single_paper
importlib.reload(test_v21_single_paper)

# Run the test
from test_v21_single_paper import test_single_paper
result = test_single_paper("O_ISAC_029")
# Out:
# ...
# 🧪 TESTING v2.1 SCHEMA ON: O_ISAC_029
# ...
#
# 📄 Loaded: /content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST/data/processed_markdowns/O_ISAC_029/O_ISAC_029/O_ISAC_029.md
#    Content length: 79,038 chars
#
# 🔄 Calling Groq LLM (llama-3.3-70b-versatile)...
#    Response length: 5,636 chars
#    Finish reason: stop
# ✅ JSON parsed successfully!
#
# ...
# 📊 v2.1 NEW FIELDS EXTRACTED:
# ...
#
# 🎯 key_contribution:
#    A novel D-band photonic-based ISAC system with full-photonic direct LFM reception and de-chirping for fiber-wireless networks
#
# 🔍 gap_addressed:
#    The limitation of traditional electronic-based ISAC systems in generating high-frequency THz signals and the impact of fiber transmission on radar performance
#
# ⚡ performance_enablers:
#    • photonic_dechirping
#    • coherent_homodyne
#    • high_bandwidth_modulator
#
# 🔧 novel_component:
#    TFLN-MZM with 110 GHz bandwidth
#
# 📐 novel_component_specs:
# ...

# %%
# ========================================
# 📄 FULL v2.1 EXTRACTION GÖRÜNTÜLEME
# ========================================
import json

# Test sonucunu oku
json_path = Config.OUTPUT_DIR + '/test_O_ISAC_029_v21.json'
with open(json_path) as f:
    data = json.load(f)

# Tamamını göster
print("=" * 70)
print("📄 O_ISAC_029 - FULL v2.1 EXTRACTION")
print("=" * 70)
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# ...
# 📄 O_ISAC_029 - FULL v2.1 EXTRACTION
# ...
# {
#   "Paper_ID": "O_ISAC_029",
#   "Study_Level": {
#     "title": "THz Integrated Sensing and Communication With Full-Photonic Direct LFM Reception and De-Chirping for D-Band Fiber-Wireless Network",
#     "authors": "Boyu Dong, Zhongya Li, Sizhe Xing, Yinjun Liu, Junhao Zhao, Ouhan Huang, Junlian Jia, Jianyang Shi, Yingjun Zhou, Haipeng Wang, Nan Chi, Junwen Zhang",
#     "year": 2025,
#     "venue": "IEEE Transactions on Microwave Theory and Techniques",
#     "doi": "10.1109/TMTT.2025.3549729",
#     "document_type": "journal",
#     "oisac_medium_class": "hybrid",
#     "carrier_band": "D-band",
#     "operational_environment": "lab",
#     "link_topology": "point_to_point",
#     "mobility_context": "static",
#     "application_domain": [
#       "6g_networks",
#       "indoor_positioning"
#     ],
# ...

# %%
# Drive'ı yeniden mount et
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# ========================================
# 🧠 STAGE 2: REASONING EXTRACTION
# ========================================
import sys
import os
# Path'i ekle
PROJECT = '/content/drive/MyDrive/AKU_WorkSpace/survey_fdgit/OISAC_PRISMA_COMST'
sys.path.insert(0, os.path.join(PROJECT, 'analysis/notebooks'))

# Şimdi import
from reasoning_extraction_v1 import extract_reasoning, run_reasoning_pipeline, generate_survey_sentences

# Test et
result = extract_reasoning("O_ISAC_029")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3431439517.py in <cell line: 0>()
#       9
#      10 # Şimdi import
# ---> 11 from reasoning_extraction_v1 import extract_reasoning, run_reasoning_pipeline, generate_survey_sentences
#      12
#      13 # Test et
#
# ModuleNotFoundError: No module named 'reasoning_extraction_v1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
